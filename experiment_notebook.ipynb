# %% [markdown]
# # Preparation

# %%
# Packages
import numpy as np
import matplotlib as mlt
import matplotlib.pyplot as plt

import ioh

from itertools import combinations

from sklearn.metrics import mean_squared_error

from sklearn.metrics import mean_absolute_error

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression, Lasso, Lars, LassoLars

from sklearn.model_selection import train_test_split

import itertools

import pandas as pd

import math

import seaborn as sns

# Py files
from graphs import *
from experiments import *
from helpers import * 

from model import Model
from walshbasis import WalshBasis
from optimizer import HillClimber

# %%
# For reproducibility
np.random.seed(42)

# %%
inter_n10k1 = get_interactions_vec(get_interactions_idx(n=10, k=1), n=10)
inter_n10k2 = get_interactions_vec(get_interactions_idx(n=10, k=2), n=10)

inter_n25k1 = get_interactions_vec(get_interactions_idx(n=25, k=1), n=25)
inter_n25k2 = get_interactions_vec(get_interactions_idx(n=25, k=2), n=25)

inter_n50k1 = get_interactions_vec(get_interactions_idx(n=50, k=1), n=50)
inter_n50k2 = get_interactions_vec(get_interactions_idx(n=50, k=2), n=50)

inter_n100k1 = get_interactions_vec(get_interactions_idx(n=100, k=1), n=100)
inter_n100k2 = get_interactions_vec(get_interactions_idx(n=100, k=2), n=100)

# %% [markdown]
# # NK-Landscapes Problem

# %% [markdown]
# ## n=10

# %% [markdown]
# ### Polynomial

# %%
NKL_ML_poly_n10k1 = experiment_nk(LinearRegression(), n=10, k=1, problem_name="NKLandscapes", interactions_nk=inter_n10k1, walsh_basis=False, csv_name="CSVs/NKL_ML_poly_n10k1")
NKL_ML_poly_n10k2 = experiment_nk(LinearRegression(), n=10, k=2, problem_name="NKLandscapes", interactions_nk=inter_n10k2, walsh_basis=False, csv_name="CSVs/NKL_ML_poly_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_poly_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_poly_n10k2

# %%
NKL_W_poly_n10k1 = experiment_nk(LinearRegression(), n=10, k=1, problem_name="NKLandscapes", interactions_nk=inter_n10k1, walsh_basis=True, csv_name="CSVs/NKL_W_poly_n10k1")
NKL_W_poly_n10k2 = experiment_nk(LinearRegression(), n=10, k=2, problem_name="NKLandscapes", interactions_nk=inter_n10k2, walsh_basis=True, csv_name="CSVs/NKL_W_poly_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_poly_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_poly_n10k2

# %% [markdown]
# ### Lars

# %%
NKL_ML_lars_n10k1 = experiment_nk(Lars(), n=10, k=1, problem_name="NKLandscapes", interactions_nk=inter_n10k1, walsh_basis=False, csv_name="CSVs/NKL_ML_lars_n10k1")
NKL_ML_lars_n10k2 = experiment_nk(Lars(), n=10, k=2, problem_name="NKLandscapes", interactions_nk=inter_n10k2, walsh_basis=False, csv_name="CSVs/NKL_ML_lars_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=2.967e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=8.089e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.723e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.723e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.046e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.726e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_lars_n10k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.812e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.061e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.061e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.061e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=2.043e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=1.801e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=1.799e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=1.561e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.684e-03, with an active set of 54 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.329e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.122e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.122e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.114e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.114e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.114e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.114e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.114e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.103e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.068e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.034e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=1.344e-02, with an active set of 20 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=1.340e-02, with an active set of 22 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=1.573e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.620e-02, with an active set of 25 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.504e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.753e-02, with an active set of 25 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.362e-02, with an active set of 25 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=9.187e-03, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.961e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.961e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.961e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.152e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.152e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.152e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.601e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.601e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.483e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.483e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.287e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.766e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.766e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.341e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.341e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.341e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.341e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.341e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.357e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.357e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.773e-05, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.773e-05, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_lars_n10k2

# %%
NKL_W_lars_n10k1 = experiment_nk(Lars(), n=10, k=1, problem_name="NKLandscapes", interactions_nk=inter_n10k1, walsh_basis=True, csv_name="CSVs/NKL_W_lars_n10k1")
NKL_W_lars_n10k2 = experiment_nk(Lars(), n=10, k=2, problem_name="NKLandscapes", interactions_nk=inter_n10k2, walsh_basis=True, csv_name="CSVs/NKL_W_lars_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=3.813e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.751e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.013e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.027e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.371e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.862e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=3.298e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=3.298e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=7.328e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_lars_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=3.420e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.710e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.070e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.070e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.070e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.393e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.635e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.635e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.042e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.365e-03, with an active set of 32 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.772e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.772e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.862e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.862e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.862e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.862e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.862e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.862e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=7.614e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=4.317e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.258e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.258e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.258e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.258e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.258e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.429e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=6.204e-03, with an active set of 30 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=3.989e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.090e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.090e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.090e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.090e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.545e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.545e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.545e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.545e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.545e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.348e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.348e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.348e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.348e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.096e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.467e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.975e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.975e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.975e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.975e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=3.428e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.714e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.714e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.714e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.714e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.872e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.872e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.872e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.872e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.398e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.398e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.398e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.398e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_lars_n10k2

# %% [markdown]
# ### Lasso

# %%
NKL_ML_las_n10k1 = experiment_nk(Lasso(alpha=1e-5), n=10, k=1, problem_name="NKLandscapes", interactions_nk=inter_n10k1, walsh_basis=False, csv_name="CSVs/NKL_ML_las_n10k1")
NKL_ML_las_n10k2 = experiment_nk(Lasso(alpha=1e-5), n=10, k=2, problem_name="NKLandscapes", interactions_nk=inter_n10k2, walsh_basis=False, csv_name="CSVs/NKL_ML_las_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.145e-05, tolerance: 8.523e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.298e-06, tolerance: 4.676e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.701e-06, tolerance: 2.721e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_las_n10k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.934e-06, tolerance: 4.078e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.980e-05, tolerance: 1.464e-05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.146e-05, tolerance: 2.409e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.266e-06, tolerance: 1.846e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.923e-05, tolerance: 1.931e-05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.337e-05, tolerance: 3.056e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.561e-06, tolerance: 1.581e-06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.852e-05, tolerance: 1.464e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.240e-05, tolerance: 2.389e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.000e-06, tolerance: 1.125e-06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.727e-05, tolerance: 1.392e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.597e-04, tolerance: 2.896e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.418e-06, tolerance: 4.942e-07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.510e-05, tolerance: 7.799e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.637e-04, tolerance: 2.401e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_las_n10k2

# %%
NKL_W_las_n10k1 = experiment_nk(Lasso(alpha=1e-5), n=10, k=1, problem_name="NKLandscapes", interactions_nk=inter_n10k1, walsh_basis=True, csv_name="CSVs/NKL_W_las_n10k1")
NKL_W_las_n10k2 = experiment_nk(Lasso(alpha=1e-5), n=10, k=2, problem_name="NKLandscapes", interactions_nk=inter_n10k1, walsh_basis=True, csv_name="CSVs/NKL_W_las_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.169e-06, tolerance: 5.444e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.781e-07, tolerance: 2.170e-07
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_las_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.612e-06, tolerance: 3.411e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.946e-06, tolerance: 1.476e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.179e-06, tolerance: 4.762e-07
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_las_n10k2

# %% [markdown]
# ### LassoLars

# %%
NKL_ML_ll_n10k1 = experiment_nk(LassoLars(alpha=1e-5), n=10, k=1, problem_name="NKLandscapes", interactions_nk=inter_n10k1, walsh_basis=False, csv_name="CSVs/NKL_ML_ll_n10k1")
NKL_ML_ll_n10k2 = experiment_nk(LassoLars(alpha=1e-5), n=10, k=2, problem_name="NKLandscapes", interactions_nk=inter_n10k2, walsh_basis=False, csv_name="CSVs/NKL_ML_ll_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.944e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.670e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.560e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=6.978e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.089e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.400e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.305e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.765e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.672e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.672e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_ll_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.385e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.062e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.062e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=5.774e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.846e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.846e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.846e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.846e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.159e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.243e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.628e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.628e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.628e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.603e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.035e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.999e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.999e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.688e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.688e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.467e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.056e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.056e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.056e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.399e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.846e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.846e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.763e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.763e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 51 iterations, i.e. alpha=1.280e-05, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 52 iterations, i.e. alpha=1.200e-05, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 52 iterations, i.e. alpha=1.050e-05, with an active set of 24 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 52 iterations, i.e. alpha=1.050e-05, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 53 iterations, alpha=1.200e-05, previous alpha=1.050e-05, with an active set of 24 regressors.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=2.274e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.156e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.156e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.137e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.137e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.067e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.067e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.059e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.059e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.038e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.038e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=9.498e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=4.818e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=4.818e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=4.818e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.939e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.121e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.121e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.183e-05, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.994e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.994e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.994e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=9.044e-03, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=4.522e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=4.522e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.903e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.903e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.903e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.186e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.167e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.167e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.462e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.705e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.705e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.705e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_ll_n10k2

# %%
NKL_W_ll_n10k1 = experiment_nk(LassoLars(alpha=1e-5), n=10, k=1, problem_name="NKLandscapes", interactions_nk=inter_n10k1, walsh_basis=True, csv_name="CSVs/NKL_W_ll_n10k1")
NKL_W_ll_n10k2 = experiment_nk(LassoLars(alpha=1e-5), n=10, k=2, problem_name="NKLandscapes", interactions_nk=inter_n10k2, walsh_basis=True, csv_name="CSVs/NKL_W_ll_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.077e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.038e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.781e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.906e-05, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.906e-05, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.170e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=5.852e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=5.747e-03, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.874e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.874e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.461e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.461e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.461e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.047e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=2.701e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.351e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.351e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.351e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.520e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.520e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.760e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.760e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_ll_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.572e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.751e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.751e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.618e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.276e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.276e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.276e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.257e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.257e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=9.106e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.553e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.553e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.418e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.922e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.922e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=2.060e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.030e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.030e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.030e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.970e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.970e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.970e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.318e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.318e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.318e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.318e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.013e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.013e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.013e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.264e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=9.696e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.848e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.848e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.665e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.665e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.515e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.515e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.515e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.333e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.333e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.333e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.333e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.824e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.824e-04, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=3.563e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.342e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.342e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.342e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.431e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.431e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.431e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.431e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.431e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.011e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.011e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.011e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.011e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.194e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.097e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.097e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.097e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_ll_n10k2

# %% [markdown]
# ## n=25

# %% [markdown]
# ### Polynomial

# %%
NKL_ML_poly_n25k1 = experiment_nk(LinearRegression(), n=25, k=1, problem_name="NKLandscapes", interactions_nk=inter_n25k1, walsh_basis=False, csv_name="CSVs/NKL_ML_poly_n25k1")
NKL_ML_poly_n25k2 = experiment_nk(LinearRegression(), n=25, k=2, problem_name="NKLandscapes", interactions_nk=inter_n25k2, walsh_basis=False, csv_name="CSVs/NKL_ML_poly_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_poly_n25k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_poly_n25k2

# %%
NKL_W_poly_n25k1 = experiment_nk(LinearRegression(), n=25, k=1, problem_name="NKLandscapes", interactions_nk=inter_n25k1, walsh_basis=True, csv_name="CSVs/NKL_W_poly_n25k1")
NKL_W_poly_n25k2 = experiment_nk(LinearRegression(), n=25, k=2, problem_name="NKLandscapes", interactions_nk=inter_n25k2, walsh_basis=True, csv_name="CSVs/NKL_W_poly_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_poly_n25k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_poly_n25k2

# %% [markdown]
# ### Lars

# %%
NKL_ML_lars_n25k1 = experiment_nk(Lars(), n=25, k=1, problem_name="NKLandscapes", interactions_nk=inter_n25k1, walsh_basis=False, csv_name="CSVs/NKL_ML_lars_n25k1")
NKL_ML_lars_n25k2 = experiment_nk(Lars(), n=25, k=2, problem_name="NKLandscapes", interactions_nk=inter_n25k2, walsh_basis=False, csv_name="CSVs/NKL_ML_lars_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.423e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.883e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.883e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.883e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.181e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.273e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=5.322e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=4.582e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.943e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.709e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.128e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.711e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.073e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.994e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.475e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.475e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.457e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.267e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.071e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=9.384e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.772e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.749e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.181e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.009e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=4.916e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.556e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.497e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.449e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.591e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.350e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.235e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.105e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.100e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.074e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.641e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.058e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.598e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.280e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=8.088e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.268e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.268e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.052e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.032e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.010e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.092e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.045e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=6.507e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=6.282e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.858e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.061e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.689e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.489e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.464e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.228e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=9.716e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=8.947e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.657e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=8.947e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=8.947e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=4.473e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=4.473e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.598e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=4.473e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=4.473e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=4.473e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=4.473e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=4.473e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_lars_n25k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.733e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.959e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.959e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.959e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.378e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.280e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.280e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.131e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.121e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.121e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.121e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.099e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.072e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.932e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.831e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.783e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.764e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.669e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.669e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.643e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.620e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.572e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.553e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.542e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.518e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.474e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.454e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.437e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.433e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.403e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.394e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.392e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.388e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.379e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.370e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.364e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.355e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.272e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.209e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.209e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.200e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.197e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.187e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.187e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.170e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.165e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.163e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.153e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.148e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.146e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.095e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.085e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.065e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.060e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.003e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=9.977e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=9.934e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=9.806e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.227e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.106e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.106e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.100e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.089e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.082e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.082e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=9.552e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=9.552e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=9.552e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=8.761e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=8.761e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=8.588e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=7.315e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=7.315e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=7.315e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=7.315e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=7.254e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=7.254e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.981e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.600e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.418e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.200e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.191e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.078e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.017e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.017e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.638e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.865e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.744e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.571e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.571e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.380e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.298e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.237e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.237e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.237e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.446e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.273e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.726e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.132e-06, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_lars_n25k2

# %%
NKL_W_lars_n25k1 = experiment_nk(Lars(), n=25, k=1, problem_name="NKLandscapes", interactions_nk=inter_n25k1, walsh_basis=True, csv_name="CSVs/NKL_W_lars_n25k1")
NKL_W_lars_n25k2 = experiment_nk(Lars(), n=25, k=2, problem_name="NKLandscapes", interactions_nk=inter_n25k2, walsh_basis=True, csv_name="CSVs/NKL_W_lars_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.006e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.006e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.006e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.505e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.337e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.259e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.153e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=6.741e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=6.348e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=6.289e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=4.034e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=3.484e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=3.262e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=2.862e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=2.744e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=2.149e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.415e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=3.791e-06, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.887e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.765e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.615e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.457e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=4.490e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.874e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.780e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.705e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.509e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.079e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.461e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.026e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.496e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.252e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.027e-05, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_lars_n25k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.840e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.191e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.911e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.911e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.911e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.911e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.911e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.613e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.610e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.555e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.554e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.548e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.560e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.516e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.506e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.425e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.412e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.382e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.368e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.337e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.329e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.296e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.293e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.288e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.255e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.247e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.244e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.241e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.233e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.227e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.224e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.219e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.213e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.199e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.191e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.191e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.185e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.183e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.177e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.176e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.169e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.165e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.163e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.150e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.141e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.140e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.139e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.137e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.129e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.122e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.115e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.108e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.096e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.089e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.079e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.076e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.075e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.072e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.065e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.050e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.042e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.035e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.029e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.028e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.026e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.013e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.006e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.004e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.002e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.909e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.842e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.765e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.567e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.531e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.487e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.448e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.422e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.406e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.376e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.299e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.267e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.232e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.219e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.202e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=9.069e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=9.057e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=8.907e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=8.875e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=8.854e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.702e-05, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.702e-05, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.309e-05, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.309e-05, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.103e-05, with an active set of 13 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.032e-05, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=8.945e-06, with an active set of 13 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=7.044e-06, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=6.039e-06, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=5.539e-06, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=4.280e-06, with an active set of 13 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=3.711e-06, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=3.474e-06, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=3.233e-06, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.016e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.707e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=4.980e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=4.614e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=4.614e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.584e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.584e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.584e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.584e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.584e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.584e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.119e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.119e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.119e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.119e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.119e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.119e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.119e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.119e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.119e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.119e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.119e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.119e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.119e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=3.119e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=3.400e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_lars_n25k2

# %% [markdown]
# ### Lasso

# %%
NKL_ML_las_n25k1 = experiment_nk(Lasso(alpha=1e-5), n=25, k=1, problem_name="NKLandscapes", interactions_nk=inter_n25k1, walsh_basis=False, csv_name="CSVs/NKL_ML_las_n25k1")
NKL_ML_las_n25k2 = experiment_nk(Lasso(alpha=1e-5), n=25, k=2, problem_name="NKLandscapes", interactions_nk=inter_n25k2, walsh_basis=False, csv_name="CSVs/NKL_ML_las_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.065e-06, tolerance: 2.099e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.941e-06, tolerance: 3.591e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.390e-06, tolerance: 4.183e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.086e-06, tolerance: 3.259e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.875e-06, tolerance: 2.069e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_las_n25k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.546e-06, tolerance: 3.586e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.787e-05, tolerance: 1.206e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.958e-05, tolerance: 1.933e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.424e-04, tolerance: 2.465e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.614e-04, tolerance: 3.547e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.370e-04, tolerance: 4.378e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.932e-06, tolerance: 3.112e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.938e-05, tolerance: 1.390e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.178e-05, tolerance: 2.523e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.176e-04, tolerance: 3.777e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.832e-04, tolerance: 4.856e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.899e-05, tolerance: 5.885e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.591e-06, tolerance: 2.970e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.169e-05, tolerance: 1.493e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.105e-04, tolerance: 2.347e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.854e-05, tolerance: 3.005e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.854e-04, tolerance: 3.970e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.013e-04, tolerance: 5.384e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.807e-06, tolerance: 1.665e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.699e-05, tolerance: 1.415e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.598e-05, tolerance: 2.205e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.206e-04, tolerance: 3.105e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.528e-04, tolerance: 4.323e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.495e-06, tolerance: 2.298e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.705e-05, tolerance: 1.427e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.202e-04, tolerance: 2.675e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.825e-04, tolerance: 3.547e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.850e-04, tolerance: 4.736e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_las_n25k2

# %%
NKL_W_las_n25k1 = experiment_nk(Lasso(alpha=1e-5), n=25, k=1, problem_name="NKLandscapes", interactions_nk=inter_n25k1, walsh_basis=True, csv_name="CSVs/NKL_W_las_n25k1")
NKL_W_las_n25k2 = experiment_nk(Lasso(alpha=1e-5), n=25, k=2, problem_name="NKLandscapes", interactions_nk=inter_n25k2, walsh_basis=True, csv_name="CSVs/NKL_W_las_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.176e-06, tolerance: 2.776e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.946e-06, tolerance: 3.778e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.513e-06, tolerance: 3.083e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.173e-05, tolerance: 6.882e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.778e-06, tolerance: 4.233e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_las_n25k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.057e-06, tolerance: 1.589e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.951e-05, tolerance: 1.390e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.311e-05, tolerance: 2.532e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.701e-05, tolerance: 3.573e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.270e-06, tolerance: 3.722e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.728e-05, tolerance: 1.623e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.768e-05, tolerance: 2.713e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.497e-06, tolerance: 2.150e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.600e-05, tolerance: 1.129e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.494e-05, tolerance: 2.781e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.505e-05, tolerance: 3.755e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.448e-06, tolerance: 1.016e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.500e-05, tolerance: 1.064e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.230e-05, tolerance: 2.481e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.953e-05, tolerance: 2.975e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.716e-06, tolerance: 8.468e-07
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.752e-05, tolerance: 1.138e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.845e-05, tolerance: 2.381e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.411e-05, tolerance: 3.389e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_las_n25k2

# %% [markdown]
# ### LassoLars

# %%
NKL_ML_ll_n25k1 = experiment_nk(LassoLars(alpha=1e-5), n=25, k=1, problem_name="NKLandscapes", interactions_nk=inter_n25k1, walsh_basis=False, csv_name="CSVs/NKL_ML_ll_n25k1")
NKL_ML_ll_n25k2 = experiment_nk(LassoLars(alpha=1e-5), n=25, k=2, problem_name="NKLandscapes", interactions_nk=inter_n25k2, walsh_basis=False, csv_name="CSVs/NKL_ML_ll_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.085e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.085e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.689e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.085e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.085e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.085e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.085e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.085e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.085e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=2.278e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=2.278e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.518e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.518e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.518e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=7.592e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=7.592e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=7.592e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=7.592e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.689e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 16 iterations, alpha=2.278e-04, previous alpha=7.592e-05, with an active set of 9 regressors.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_ll_n25k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.456e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=6.859e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=6.859e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 11 iterations, alpha=6.196e-03, previous alpha=6.089e-03, with an active set of 8 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.298e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=3.206e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.228e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.228e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.197e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.197e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.197e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.405e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.405e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.405e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.405e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.405e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.405e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.405e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.405e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.405e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=8.816e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=7.924e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=7.924e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=7.924e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=7.924e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=7.672e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=7.616e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=4.545e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=3.839e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=3.501e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=2.206e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.689e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.598e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=5.835e-05, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.541e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.777e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.251e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=6.253e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.066e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.066e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.903e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.903e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.740e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.740e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.740e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.740e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.577e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.577e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.577e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.577e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.577e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.577e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.414e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.414e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.414e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.414e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.251e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.088e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.818e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=3.578e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=3.578e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=3.431e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.302e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.302e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.201e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.173e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.072e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.072e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.942e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.942e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.942e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.929e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.842e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.838e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.838e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.813e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.813e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.684e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.684e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.771e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.583e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.554e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.453e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.453e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.453e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.453e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.450e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.349e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.349e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.324e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.771e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.220e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.220e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.220e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.191e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.090e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.090e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.090e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.090e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 12 iterations, alpha=5.033e-03, previous alpha=2.062e-03, with an active set of 9 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.233e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=9.157e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=7.736e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=7.736e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 12 iterations, alpha=4.110e-03, previous alpha=4.035e-03, with an active set of 7 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=5.435e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.766e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 8 iterations, alpha=3.566e-03, previous alpha=2.991e-03, with an active set of 7 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_ll_n25k2

# %%
NKL_W_ll_n25k1 = experiment_nk(LassoLars(alpha=1e-5), n=25, k=1, problem_name="NKLandscapes", interactions_nk=inter_n25k1, walsh_basis=True, csv_name="CSVs/NKL_W_ll_n25k1")
NKL_W_ll_n25k2 = experiment_nk(LassoLars(alpha=1e-5), n=25, k=2, problem_name="NKLandscapes", interactions_nk=inter_n25k2, walsh_basis=True, csv_name="CSVs/NKL_W_ll_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=8.427e-04, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=8.100e-04, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=6.462e-04, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=4.240e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=4.091e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=3.288e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=3.214e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 17 iterations, alpha=4.240e-04, previous alpha=2.879e-04, with an active set of 10 regressors.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.396e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 15 iterations, alpha=1.396e-03, previous alpha=1.396e-03, with an active set of 10 regressors.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_ll_n25k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.062e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.062e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.917e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.917e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.531e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.531e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.531e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.458e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.458e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.366e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.366e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.366e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.366e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.366e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.242e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.242e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.242e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.242e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.154e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.154e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.154e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.154e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.154e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.154e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.154e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.151e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.066e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.066e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.066e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.066e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.066e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.066e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.066e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.785e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.785e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=9.785e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 16 iterations, alpha=1.101e-02, previous alpha=9.785e-03, with an active set of 13 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.926e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.926e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=9.629e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=8.206e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.793e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.477e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.853e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.853e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=2.116e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.848e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.761e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.761e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.761e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.761e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.753e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.753e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.753e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 18 iterations, alpha=1.761e-03, previous alpha=1.753e-03, with an active set of 11 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=3.922e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.639e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.698e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.698e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.698e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.698e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.698e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.698e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.320e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.320e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.320e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.128e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.128e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.128e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.128e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.128e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.128e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.128e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=7.084e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=7.084e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=7.084e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=7.084e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=7.084e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.640e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.640e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.640e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.640e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.640e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.789e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.789e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.789e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.789e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.789e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.938e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.938e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.938e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.938e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 12 iterations, alpha=8.274e-03, previous alpha=4.938e-03, with an active set of 11 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.910e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.594e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.594e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.363e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.363e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.873e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=8.352e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=8.352e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=8.352e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=8.352e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.352e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.352e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=7.329e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=6.960e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=6.960e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=6.960e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=6.960e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=6.960e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=6.960e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 12 iterations, alpha=8.352e-03, previous alpha=6.960e-03, with an active set of 11 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=6.293e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=3.292e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=3.292e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.292e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.292e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.292e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.292e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.292e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.646e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.646e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.646e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.646e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.646e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.646e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.473e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.473e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.473e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.473e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.473e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.473e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.473e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.473e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.473e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.126e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.906e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.734e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.734e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.734e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.734e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.734e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_ll_n25k2

# %% [markdown]
# ## n=50

# %% [markdown]
# ### Polynomial

# %%
NKL_ML_poly_n50k1 = experiment_nk(LinearRegression(), n=50, k=1, problem_name="NKLandscapes", interactions_nk=inter_n50k1, walsh_basis=False, csv_name="CSVs/NKL_ML_poly_n50k1")
NKL_ML_poly_n50k2 = experiment_nk(LinearRegression(), n=50, k=2, problem_name="NKLandscapes", interactions_nk=inter_n50k2, walsh_basis=False, csv_name="CSVs/NKL_ML_poly_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_poly_n50k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_poly_n50k2

# %%
NKL_W_poly_n50k1 = experiment_nk(LinearRegression(), n=50, k=1, problem_name="NKLandscapes", interactions_nk=inter_n50k1, walsh_basis=True, csv_name="CSVs/NKL_W_poly_n50k1")
NKL_W_poly_n50k2 = experiment_nk(LinearRegression(), n=50, k=2, problem_name="NKLandscapes", interactions_nk=inter_n50k2, walsh_basis=True, csv_name="CSVs/NKL_W_poly_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_poly_n50k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_poly_n50k2

# %% [markdown]
# ### Lars

# %%
NKL_ML_lars_n50k1 = experiment_nk(Lars(), n=50, k=1, problem_name="NKLandscapes", interactions_nk=inter_n50k1, walsh_basis=False, csv_name="CSVs/NKL_ML_lars_n50k1")
NKL_ML_lars_n50k2 = experiment_nk(Lars(), n=50, k=2, problem_name="NKLandscapes", interactions_nk=inter_n50k2, walsh_basis=False, csv_name="CSVs/NKL_ML_lars_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=4.891e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=4.547e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=3.589e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=3.022e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.871e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.771e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.754e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.736e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.580e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.367e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.282e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.072e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=9.613e-05, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=9.390e-05, with an active set of 28 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=5.719e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=4.649e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=4.580e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=4.380e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=3.483e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=3.122e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=2.598e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=2.441e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=2.247e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=2.246e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=1.999e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=1.834e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=1.748e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=1.121e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=9.829e-06, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=7.394e-06, with an active set of 29 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=6.424e-06, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=5.047e-06, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=2.293e-06, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=1.939e-06, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=7.305e-07, with an active set of 29 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.865e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=2.387e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.361e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.100e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.016e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.986e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.943e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.761e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.508e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.392e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.331e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.200e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.017e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=7.765e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=7.468e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=6.840e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=6.495e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=5.125e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=4.515e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=4.223e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=3.961e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=3.882e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=3.765e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=3.272e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=3.061e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.809e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.722e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.234e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.180e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.715e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.300e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.297e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.240e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.007e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=9.128e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=6.699e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=6.033e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=4.571e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=1.097e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=4.046e-04, with an active set of 25 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=3.461e-04, with an active set of 25 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=2.923e-04, with an active set of 25 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=2.860e-04, with an active set of 25 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=3.177e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.963e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.707e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.447e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.434e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.340e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.183e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.159e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.627e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.430e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.252e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.213e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.111e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.085e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=7.988e-05, with an active set of 26 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=6.454e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=6.333e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=5.682e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=5.496e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=4.700e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=4.165e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=3.897e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=2.315e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=2.509e-06, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=2.027e-06, with an active set of 32 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=1.866e-06, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=1.639e-06, with an active set of 32 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.079e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.026e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=9.134e-04, with an active set of 25 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=7.565e-04, with an active set of 25 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=7.530e-04, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=6.970e-04, with an active set of 25 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=6.228e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=6.200e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=5.488e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.732e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=3.884e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=3.673e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.958e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.571e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.444e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.984e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.975e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.786e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.533e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.495e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.473e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.462e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.408e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=9.036e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=5.786e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=5.671e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=4.436e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=4.140e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=9.119e-06, with an active set of 27 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=3.589e-06, with an active set of 27 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.833e-06, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.857e-06, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.077e-06, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_lars_n50k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=5.484e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=5.346e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=5.337e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=5.300e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=3.131e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=6.590e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_lars_n50k2

# %%
NKL_W_lars_n50k1 = experiment_nk(Lars(), n=50, k=1, problem_name="NKLandscapes", interactions_nk=inter_n50k1, walsh_basis=True, csv_name="CSVs/NKL_W_lars_n50k1")
NKL_W_lars_n50k2 = experiment_nk(Lars(), n=50, k=2, problem_name="NKLandscapes", interactions_nk=inter_n50k2, walsh_basis=True, csv_name="CSVs/NKL_W_lars_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=2.617e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.526e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=3.062e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=2.799e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=2.668e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.490e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.478e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=2.252e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 49 iterations, i.e. alpha=2.018e-03, with an active set of 39 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.752e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.747e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.694e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_lars_n50k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=7.571e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 43 iterations, i.e. alpha=7.969e-03, with an active set of 32 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.831e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_lars_n50k2

# %% [markdown]
# ### Lasso

# %%
NKL_ML_las_n50k1 = experiment_nk(Lasso(alpha=1e-5), n=50, k=1, problem_name="NKLandscapes", interactions_nk=inter_n50k1, walsh_basis=False, csv_name="CSVs/NKL_ML_las_n50k1")
NKL_ML_las_n50k2 = experiment_nk(Lasso(alpha=1e-5), n=50, k=2, problem_name="NKLandscapes", interactions_nk=inter_n50k2, walsh_basis=False, csv_name="CSVs/NKL_ML_las_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.704e-06, tolerance: 2.801e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.891e-06, tolerance: 3.317e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.196e-06, tolerance: 1.569e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.774e-06, tolerance: 2.514e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.655e-06, tolerance: 2.722e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_las_n50k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.666e-06, tolerance: 2.332e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.748e-05, tolerance: 1.290e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.393e-05, tolerance: 2.098e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.427e-04, tolerance: 3.148e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.488e-05, tolerance: 4.284e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.522e-04, tolerance: 5.041e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.722e-06, tolerance: 2.426e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.647e-05, tolerance: 1.304e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.640e-04, tolerance: 2.254e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.074e-04, tolerance: 3.260e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.317e-05, tolerance: 4.458e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.560e-04, tolerance: 5.609e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.240e-04, tolerance: 6.468e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.318e-06, tolerance: 1.836e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.760e-05, tolerance: 1.390e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.025e-05, tolerance: 2.521e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.206e-04, tolerance: 3.684e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.071e-04, tolerance: 4.592e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.673e-04, tolerance: 5.488e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.490e-05, tolerance: 6.461e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.239e-05, tolerance: 3.788e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.783e-05, tolerance: 1.572e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.481e-05, tolerance: 2.658e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.355e-04, tolerance: 3.668e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.258e-05, tolerance: 4.629e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.019e-04, tolerance: 5.789e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.508e-04, tolerance: 6.885e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.178e-06, tolerance: 9.509e-07
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.102e-05, tolerance: 1.106e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.691e-04, tolerance: 1.947e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.337e-05, tolerance: 2.779e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.389e-05, tolerance: 3.859e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.549e-04, tolerance: 4.831e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_las_n50k2

# %%
NKL_W_las_n50k1 = experiment_nk(Lasso(alpha=1e-5), n=50, k=1, problem_name="NKLandscapes", interactions_nk=inter_n50k1, walsh_basis=True, csv_name="CSVs/NKL_W_las_n50k1")
NKL_W_las_n50k2 = experiment_nk(Lasso(alpha=1e-5), n=50, k=2, problem_name="NKLandscapes", interactions_nk=inter_n50k2, walsh_basis=True, csv_name="CSVs/NKL_W_las_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.268e-05, tolerance: 5.779e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.563e-06, tolerance: 2.074e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.798e-06, tolerance: 2.004e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.551e-06, tolerance: 2.263e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.918e-06, tolerance: 1.663e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_las_n50k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.407e-06, tolerance: 2.993e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.711e-05, tolerance: 1.267e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.125e-05, tolerance: 2.395e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.253e-06, tolerance: 1.823e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.533e-05, tolerance: 1.024e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.370e-05, tolerance: 2.043e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.326e-06, tolerance: 3.077e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.752e-05, tolerance: 1.459e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.252e-05, tolerance: 2.669e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.322e-06, tolerance: 3.133e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.422e-05, tolerance: 1.278e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.787e-05, tolerance: 2.381e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.801e-05, tolerance: 3.518e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.846e-06, tolerance: 2.974e-06
#   model = cd_fast.enet_coordinate_descent(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.550e-05, tolerance: 1.289e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.718e-05, tolerance: 2.137e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.578e-05, tolerance: 3.303e-05
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_las_n50k2

# %% [markdown]
# ### LassoLars

# %%
NKL_ML_ll_n50k1 = experiment_nk(LassoLars(alpha=1e-5), n=50, k=1, problem_name="NKLandscapes", interactions_nk=inter_n50k1, walsh_basis=False, csv_name="CSVs/NKL_ML_ll_n50k1")
NKL_ML_ll_n50k2 = experiment_nk(LassoLars(alpha=1e-5), n=50, k=2, problem_name="NKLandscapes", interactions_nk=inter_n50k2, walsh_basis=False, csv_name="CSVs/NKL_ML_ll_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_ll_n50k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=1.341e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 49 iterations, alpha=4.686e-04, previous alpha=4.686e-04, with an active set of 24 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=4.041e-04, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.005e-04, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.004e-04, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.975e-04, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.943e-04, with an active set of 24 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.943e-04, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 37 iterations, alpha=4.005e-04, previous alpha=3.940e-04, with an active set of 24 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_ML_ll_n50k2

# %%
NKL_W_ll_n50k1 = experiment_nk(LassoLars(alpha=1e-5), n=50, k=1, problem_name="NKLandscapes", interactions_nk=inter_n50k1, walsh_basis=True, csv_name="CSVs/NKL_W_ll_n50k1")
NKL_W_ll_n50k2 = experiment_nk(LassoLars(alpha=1e-5), n=50, k=2, problem_name="NKLandscapes", interactions_nk=inter_n50k2, walsh_basis=True, csv_name="CSVs/NKL_W_ll_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_ll_n50k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=1.192e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=1.192e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 105 iterations, i.e. alpha=1.192e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 110 iterations, i.e. alpha=1.192e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 111 iterations, alpha=1.192e-03, previous alpha=1.192e-03, with an active set of 28 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 109 iterations, i.e. alpha=1.469e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 133 iterations, i.e. alpha=7.343e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 136 iterations, alpha=7.343e-04, previous alpha=7.343e-04, with an active set of 27 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_ll_n50k2

# %% [markdown]
# ## n=100

# %% [markdown]
# ### Polynomial

# %%
NKL_ML_poly_n100k1 = experiment_nk(LinearRegression(), n=100, k=1, problem_name="NKLandscapes", interactions_nk=inter_n100k1, walsh_basis=False, csv_name="CSVs/NKL_ML_poly_n100k1")
NKL_ML_poly_n100k2 = experiment_nk(LinearRegression(), n=100, k=2, problem_name="NKLandscapes", interactions_nk=inter_n100k2, walsh_basis=False, csv_name="CSVs/NKL_ML_poly_n100k2")

# %%
NKL_W_poly_n100k1 = experiment_nk(LinearRegression(), n=100, k=1, problem_name="NKLandscapes", interactions_nk=inter_n100k1, walsh_basis=True, csv_name="CSVs/NKL_W_poly_n100k1")
NKL_W_poly_n100k2 = experiment_nk(LinearRegression(), n=100, k=2, problem_name="NKLandscapes", interactions_nk=inter_n100k1, walsh_basis=True, csv_name="CSVs/NKL_W_poly_n100k2")

# %% [markdown]
# ### Lars

# %%
NKL_ML_lars_n100k1 = experiment_nk(Lars(), n=100, k=1, problem_name="NKLandscapes", interactions_nk=inter_n100k1, walsh_basis=False, csv_name="CSVs/NKL_ML_lars_n100k1")
NKL_ML_lars_n100k2 = experiment_nk(Lars(), n=100, k=2, problem_name="NKLandscapes", interactions_nk=inter_n100k2, walsh_basis=False, csv_name="CSVs/NKL_ML_lars_n100k2")

# %%
NKL_W_lars_n100k1 = experiment_nk(Lars(), n=100, k=1, problem_name="NKLandscapes", interactions_nk=inter_n100k1, walsh_basis=True, csv_name="CSVs/NKL_W_lars_n100k1")
NKL_W_lars_n100k2 = experiment_nk(Lars(), n=100, k=2, problem_name="NKLandscapes", interactions_nk=inter_n100k2, walsh_basis=True, csv_name="CSVs/NKL_W_lars_n100k2")

# %% [markdown]
# ### Lasso

# %%
NKL_ML_las_n100k1 = experiment_nk(Lasso(alpha=1e-5), n=100, k=1, problem_name="NKLandscapes", interactions_nk=inter_n100k1, walsh_basis=False, csv_name="CSVs/NKL_ML_las_n100k1")
NKL_ML_las_n100k2 = experiment_nk(Lasso(alpha=1e-5), n=100, k=2, problem_name="NKLandscapes", interactions_nk=inter_n100k2, walsh_basis=False, csv_name="CSVs/NKL_ML_las_n100k2")

# %%
NKL_W_las_n100k1 = experiment_nk(Lasso(alpha=1e-5), n=100, k=1, problem_name="NKLandscapes", interactions_nk=inter_n100k1, walsh_basis=True, csv_name="CSVs/NKL_W_las_n100k1")
NKL_W_las_n100k2 = experiment_nk(Lasso(alpha=1e-5), n=100, k=2, problem_name="NKLandscapes", interactions_nk=inter_n100k2, walsh_basis=True, csv_name="CSVs/NKL_W_las_n100k2")

# %% [markdown]
# ### LassoLars

# %%
NKL_ML_ll_n100k1 = experiment_nk(LassoLars(alpha=1e-5), n=100, k=1, problem_name="NKLandscapes", interactions_nk=inter_n100k1, walsh_basis=False, csv_name="CSVs/NKL_ML_ll_n100k1")
NKL_ML_ll_n100k2 = experiment_nk(LassoLars(alpha=1e-5), n=100, k=2, problem_name="NKLandscapes", interactions_nk=inter_n100k2, walsh_basis=False, csv_name="CSVs/NKL_ML_ll_n100k2")

# %%
NKL_W_ll_n100k1 = experiment_nk(LassoLars(alpha=1e-5), n=100, k=1, problem_name="NKLandscapes", interactions_nk=inter_n100k1, walsh_basis=True, csv_name="CSVs/NKL_W_ll_n100k1")
NKL_W_ll_n100k2 = experiment_nk(LassoLars(alpha=1e-5), n=100, k=2, problem_name="NKLandscapes", interactions_nk=inter_n100k2, walsh_basis=True, csv_name="CSVs/NKL_W_ll_n100k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_ll_n100k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/NKL_W_ll_n100k2

# %% [markdown]
# # OneMax with W-Model Epistasis Problem

# %% [markdown]
# ## n=10

# %% [markdown]
# ### Polynomial

# %%
OM_ML_poly_n10k1 = experiment_nk(LinearRegression(), n=10, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k1, walsh_basis=False, csv_name="CSVs/OM_ML_poly_n10k1")
OM_ML_poly_n10k2 = experiment_nk(LinearRegression(), n=10, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k2, walsh_basis=False, csv_name="CSVs/OM_ML_poly_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_poly_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_poly_n10k2

# %%
OM_W_poly_n10k1 = experiment_nk(LinearRegression(), n=10, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k1, walsh_basis=True, csv_name="CSVs/OM_W_poly_n10k1")
OM_W_poly_n10k2 = experiment_nk(LinearRegression(), n=10, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k2, walsh_basis=True, csv_name="CSVs/OM_W_poly_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_poly_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_poly_n10k2

# %% [markdown]
# ### Lars

# %%
OM_ML_lars_n10k1 = experiment_nk(Lars(), n=10, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k1, walsh_basis=False, csv_name="CSVs/OM_ML_lars_n10k1")
OM_ML_lars_n10k2 = experiment_nk(Lars(), n=10, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k2, walsh_basis=False, csv_name="CSVs/OM_ML_lars_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.667e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.667e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.333e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.619e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.810e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.810e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_lars_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.800e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.257e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.257e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.714e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.714e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.714e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.300e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.300e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.300e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.300e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.143e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.143e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.429e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.429e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.000e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=2.400e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.600e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.600e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.600e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=8.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=8.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=8.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=8.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=8.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=4.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=3.519e-01, with an active set of 54 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.000e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.000e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_lars_n10k2

# %%
OM_W_lars_n10k1 = experiment_nk(Lars(), n=10, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k1, walsh_basis=True, csv_name="CSVs/OM_W_lars_n10k1")
OM_W_lars_n10k2 = experiment_nk(Lars(), n=10, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k2, walsh_basis=True, csv_name="CSVs/OM_W_lars_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.500e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_lars_n10k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.286e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.286e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=2.286e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.143e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 29 iterations, i.e. alpha=2.939e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.000e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.667e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.667e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.778e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.778e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.778e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.778e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.778e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.778e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.889e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.889e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.889e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.889e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.889e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.444e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=4.515e-02, with an active set of 26 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=4.965e-02, with an active set of 32 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.571e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.571e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.571e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.571e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.932e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=1.806e-01, with an active set of 29 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.782e-01, with an active set of 31 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.397e-01, with an active set of 31 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=1.336e-01, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 48 iterations, i.e. alpha=1.378e-01, with an active set of 37 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 50 iterations, i.e. alpha=1.135e-01, with an active set of 39 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=8.000e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=4.667e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=4.667e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.889e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.889e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.889e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.667e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.667e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.556e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.556e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.444e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.222e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.222e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.222e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.151e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.145e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.091e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=9.170e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.559e-02, with an active set of 54 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_lars_n10k2

# %% [markdown]
# ### Lasso

# %%
OM_ML_las_n10k1 = experiment_nk(Lasso(alpha=1e-5), n=10, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k1, walsh_basis=False, csv_name="CSVs/OM_ML_las_n10k1")
OM_ML_las_n10k2 = experiment_nk(Lasso(alpha=1e-5), n=10, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k2, walsh_basis=False, csv_name="CSVs/OM_ML_las_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_las_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.898e-03, tolerance: 5.296e-03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.150e-02, tolerance: 1.044e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.053e+00, tolerance: 1.479e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.668e-03, tolerance: 4.600e-03
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.688e-02, tolerance: 1.126e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.521e-01, tolerance: 1.644e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.548e-03, tolerance: 5.400e-03
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.740e+00, tolerance: 1.845e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.232e-03, tolerance: 4.800e-03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.653e-02, tolerance: 1.032e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.387e+00, tolerance: 1.658e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.118e-02, tolerance: 1.176e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.865e+00, tolerance: 1.700e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_las_n10k2

# %%
OM_W_las_n10k1 = experiment_nk(Lasso(alpha=1e-5), n=10, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k1, walsh_basis=True, csv_name="CSVs/OM_W_las_n10k1")
OM_W_las_n10k2 = experiment_nk(Lasso(alpha=1e-5), n=10, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k1, walsh_basis=True, csv_name="CSVs/OM_W_las_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_las_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_las_n10k2

# %% [markdown]
# ### LassoLars

# %%
OM_ML_ll_n10k1 = experiment_nk(LassoLars(alpha=1e-5), n=10, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k1, walsh_basis=False, csv_name="CSVs/OM_ML_ll_n10k1")
OM_ML_ll_n10k2 = experiment_nk(LassoLars(alpha=1e-5), n=10, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k2, walsh_basis=False, csv_name="CSVs/OM_ML_ll_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.306e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.306e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.306e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.200e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.200e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.200e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 4 iterations, alpha=1.000e-01, previous alpha=6.000e-02, with an active set of 3 regressors.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 10 iterations, alpha=1.852e-02, previous alpha=9.913e-03, with an active set of 9 regressors.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_ll_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=5.275e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.857e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.747e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.747e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.747e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.747e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.527e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=3.297e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.198e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.198e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.099e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=3.200e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.600e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.600e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.500e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.500e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.500e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=7.500e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=7.500e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=7.500e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=2.000e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.667e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.667e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 4 iterations, alpha=1.333e-01, previous alpha=1.111e-01, with an active set of 3 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=3.000e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.750e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.750e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.313e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.313e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.188e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.063e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.063e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=7.188e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.937e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.750e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.750e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.125e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.812e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.812e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.812e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.812e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 43 iterations, alpha=5.201e-04, previous alpha=5.201e-04, with an active set of 24 regressors.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 111 iterations, alpha=1.114e-02, previous alpha=1.114e-02, with an active set of 44 regressors.
#   warnings.warn(
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_ll_n10k2

# %%
OM_W_ll_n10k1 = experiment_nk(LassoLars(alpha=1e-5), n=10, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k1, walsh_basis=True, csv_name="CSVs/OM_W_ll_n10k1")
OM_W_ll_n10k2 = experiment_nk(LassoLars(alpha=1e-5), n=10, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n10k2, walsh_basis=True, csv_name="CSVs/OM_W_ll_n10k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.778e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.778e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.889e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.889e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.000e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.000e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.000e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.000e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.000e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_ll_n10k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.200e+00, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=6.000e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.000e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.000e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=4.000e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.500e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.500e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.500e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.500e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.500e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.500e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.500e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.000e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.000e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.000e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.000e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.000e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=5.000e-02, with an active set of 3 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=5.000e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.000e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_ll_n10k2

# %% [markdown]
# ## n=25

# %% [markdown]
# ### Polynomial

# %%
OM_ML_poly_n25k1 = experiment_nk(LinearRegression(), n=25, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k1, walsh_basis=False, csv_name="CSVs/OM_ML_poly_n25k1")
OM_ML_poly_n25k2 = experiment_nk(LinearRegression(), n=25, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k2, walsh_basis=False, csv_name="CSVs/OM_ML_poly_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_poly_n25k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_poly_n25k2

# %%
OM_W_poly_n25k1 = experiment_nk(LinearRegression(), n=25, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k1, walsh_basis=True, csv_name="CSVs/OM_W_poly_n25k1")
OM_W_poly_n25k2 = experiment_nk(LinearRegression(), n=25, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k2, walsh_basis=True, csv_name="CSVs/OM_W_poly_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_poly_n25k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_poly_n25k2

# %% [markdown]
# ### Lars

# %%
OM_ML_lars_n25k1 = experiment_nk(Lars(), n=25, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k1, walsh_basis=False, csv_name="CSVs/OM_ML_lars_n25k1")
OM_ML_lars_n25k2 = experiment_nk(Lars(), n=25, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k2, walsh_basis=False, csv_name="CSVs/OM_ML_lars_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.221e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.135e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.135e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.033e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.802e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.631e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.601e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.338e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=5.991e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=5.620e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.495e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.446e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.886e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.324e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=2.604e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.724e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.330e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.269e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=9.546e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=9.272e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.059e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=4.081e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=4.072e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.342e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.171e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.768e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.697e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.446e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.869e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.858e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.428e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.225e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.034e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.310e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=8.675e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=5.366e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.469e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.097e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=9.924e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.528e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=7.501e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=7.060e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.667e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.303e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.332e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.864e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.594e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.355e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.151e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.505e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.126e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.676e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.111e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.024e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=9.266e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=7.689e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=7.602e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=6.435e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=6.355e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=4.619e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.994e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=2.717e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.951e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.866e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=9.556e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=8.007e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_lars_n25k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.143e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.000e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.923e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.554e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.689e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.474e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.224e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.055e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.975e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.954e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.598e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.954e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.869e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.657e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.789e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.789e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.784e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.704e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.704e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.704e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.700e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.829e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.624e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.620e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.620e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.620e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.620e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.620e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.586e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.534e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.454e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.454e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.450e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.450e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.374e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.370e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.290e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.205e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.201e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.121e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.121e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.121e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.108e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.099e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.099e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.099e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.041e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.019e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.019e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.019e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=9.340e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=9.340e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=9.340e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.495e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=9.299e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=9.299e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=8.540e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.598e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=8.540e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=8.540e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=8.540e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=8.499e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.267e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.267e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.267e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.267e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.267e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.267e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.267e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.267e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.267e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.344e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.210e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=9.333e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=9.333e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=9.333e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=9.333e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=9.333e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=9.333e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.657e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.000e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.000e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.000e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.000e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.000e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.451e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.000e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.000e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.000e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=8.000e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.333e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.667e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.333e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.333e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.333e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.381e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_lars_n25k2

# %%
OM_W_lars_n25k1 = experiment_nk(Lars(), n=25, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k1, walsh_basis=True, csv_name="CSVs/OM_W_lars_n25k1")
OM_W_lars_n25k2 = experiment_nk(Lars(), n=25, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k2, walsh_basis=True, csv_name="CSVs/OM_W_lars_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.607e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.184e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.123e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=9.739e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=6.848e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=6.753e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=6.273e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.627e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=5.046e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=4.085e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=2.516e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=2.210e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.925e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.377e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.060e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.050e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=9.889e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=7.575e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.076e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.865e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.608e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=2.359e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.516e-04, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=5.259e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.415e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.311e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=4.081e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=3.978e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.644e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.437e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.776e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.775e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.704e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.575e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.478e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=8.010e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.370e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=5.319e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.311e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.077e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.794e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=2.633e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.426e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.088e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_lars_n25k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=6.000e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=6.000e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.000e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.000e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.000e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.000e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=6.000e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=6.000e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=6.000e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=4.000e-01, with an active set of 11 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.000e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.000e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.000e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.000e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.000e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.000e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.000e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=4.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=4.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=4.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=4.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=4.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=4.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=2.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=2.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=2.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=2.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=2.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=2.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=2.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=2.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=2.000e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=4.853e-01, with an active set of 52 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=5.251e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.048e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.048e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.048e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.048e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.048e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.286e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=4.286e-01, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=4.286e-01, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=4.286e-01, with an active set of 11 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=4.286e-01, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.286e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.286e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.286e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.286e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.286e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.524e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.524e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.524e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.524e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.524e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.048e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.048e-01, with an active set of 12 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.905e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.905e-01, with an active set of 13 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.806e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.805e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.726e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.649e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.614e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.609e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.532e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.473e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.391e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.367e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.347e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.314e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.308e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.305e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.289e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.281e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.277e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.268e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=2.254e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=8.078e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=7.767e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=7.739e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=7.225e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=7.202e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=6.920e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=6.920e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=6.637e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=6.072e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=5.734e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=5.727e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=5.479e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=5.395e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=5.169e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.689e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.378e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.067e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.011e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=3.756e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=3.313e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.994e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.966e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.937e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.740e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.711e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.429e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.401e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.234e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.187e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.869e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.836e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.741e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.525e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.336e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.327e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.141e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.802e-04, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.519e-04, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=3.107e-04, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.695e-04, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.412e-04, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_lars_n25k2

# %% [markdown]
# ### Lasso

# %%
OM_ML_las_n25k1 = experiment_nk(Lasso(alpha=1e-5), n=25, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k1, walsh_basis=False, csv_name="CSVs/OM_ML_las_n25k1")
OM_ML_las_n25k2 = experiment_nk(Lasso(alpha=1e-5), n=25, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k2, walsh_basis=False, csv_name="CSVs/OM_ML_las_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.590e+00, tolerance: 1.272e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.760e-01, tolerance: 2.103e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_las_n25k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.701e-02, tolerance: 5.210e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.302e-01, tolerance: 7.857e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.279e-01, tolerance: 1.090e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.920e-01, tolerance: 1.330e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.762e-01, tolerance: 1.508e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.688e+00, tolerance: 1.773e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.705e+01, tolerance: 1.989e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.453e+01, tolerance: 2.162e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.630e+01, tolerance: 2.436e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.515e+00, tolerance: 2.662e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.139e-02, tolerance: 4.796e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.609e-01, tolerance: 7.800e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.525e-01, tolerance: 1.054e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.061e-01, tolerance: 1.246e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.451e-01, tolerance: 1.509e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.160e+00, tolerance: 1.764e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.884e+01, tolerance: 2.030e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.268e+02, tolerance: 2.254e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.466e+02, tolerance: 2.498e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.387e+01, tolerance: 2.780e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.955e+00, tolerance: 2.998e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.268e-02, tolerance: 2.134e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.014e-02, tolerance: 4.258e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.462e-01, tolerance: 6.311e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.577e-01, tolerance: 9.064e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.043e-01, tolerance: 1.046e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.238e-01, tolerance: 1.398e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.944e+00, tolerance: 1.700e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.521e+01, tolerance: 1.936e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.287e+02, tolerance: 2.174e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.634e+02, tolerance: 2.454e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.500e+00, tolerance: 2.712e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.731e-02, tolerance: 5.673e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.562e-01, tolerance: 8.202e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.465e-01, tolerance: 1.000e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.205e-01, tolerance: 1.232e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.310e-01, tolerance: 1.427e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.224e+00, tolerance: 1.695e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.725e+01, tolerance: 1.952e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.570e+02, tolerance: 2.276e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.500e+02, tolerance: 2.426e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.067e+00, tolerance: 2.660e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.310e-02, tolerance: 4.813e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.512e-01, tolerance: 7.176e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.503e-01, tolerance: 9.301e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.170e-01, tolerance: 1.205e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.271e-01, tolerance: 1.415e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.780e+00, tolerance: 1.752e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.983e+01, tolerance: 1.897e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.315e+02, tolerance: 2.156e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.890e+01, tolerance: 2.334e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_las_n25k2

# %%
OM_W_las_n25k1 = experiment_nk(Lasso(alpha=1e-5), n=25, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k1, walsh_basis=True, csv_name="CSVs/OM_W_las_n25k1")
OM_W_las_n25k2 = experiment_nk(Lasso(alpha=1e-5), n=25, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k2, walsh_basis=True, csv_name="CSVs/OM_W_las_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.402e+00, tolerance: 1.208e-02
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_las_n25k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.760e-01, tolerance: 1.595e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.276e+01, tolerance: 1.839e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.946e-01, tolerance: 2.155e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.325e+01, tolerance: 2.383e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.348e+00, tolerance: 2.642e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.464e+01, tolerance: 2.050e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.186e+01, tolerance: 2.172e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.610e+00, tolerance: 2.372e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.268e+01, tolerance: 2.318e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_las_n25k2

# %% [markdown]
# ### LassoLars

# %%
OM_ML_ll_n25k1 = experiment_nk(LassoLars(alpha=1e-5), n=25, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k1, walsh_basis=False, csv_name="CSVs/OM_ML_ll_n25k1")
OM_ML_ll_n25k2 = experiment_nk(LassoLars(alpha=1e-5), n=25, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k2, walsh_basis=False, csv_name="CSVs/OM_ML_ll_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=6.000e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=6.000e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=6.000e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=6.000e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=6.000e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=2.509e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.070e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.033e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.035e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=6.762e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=5.785e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.657e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=5.080e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=4.768e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=4.398e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=2.658e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=2.599e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=2.071e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=2.052e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.387e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.368e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.349e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.657e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=7.419e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=3.174e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=3.143e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=3.872e-04, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.186e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.500e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.250e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.000e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=7.500e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=7.500e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=7.500e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.000e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.000e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.500e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.500e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=4.156e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.508e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.689e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 14 iterations, alpha=4.085e-02, previous alpha=3.428e-02, with an active set of 9 regressors.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_ll_n25k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.000e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.000e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=9.646e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.879e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.121e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.768e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.505e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=7.526e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=7.526e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=7.526e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=7.526e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.449e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.449e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.449e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.449e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.449e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.449e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.258e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.258e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.258e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.258e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.857e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.857e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.857e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.857e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.666e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.666e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.666e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.666e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.666e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.631e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.631e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.631e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.631e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.631e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.230e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.230e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.230e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.038e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.038e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.038e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.038e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.038e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.038e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.038e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.038e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.038e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.689e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.038e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.003e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.847e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.847e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.847e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.847e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.446e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.446e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.446e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.446e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.446e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.411e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.411e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.411e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.411e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.411e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.771e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.411e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.411e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.411e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.254e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.495e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.254e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.254e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.220e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.220e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.220e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=6.272e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.923e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.923e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.923e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.923e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.923e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.923e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=5.923e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.916e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.916e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=3.484e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=3.484e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.846e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.538e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.538e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.538e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.538e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.538e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.009e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.009e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.541e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.009e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.009e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 16 iterations, alpha=1.009e-01, previous alpha=1.009e-01, with an active set of 9 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=9.429e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.929e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.929e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=4.698e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 6 iterations, alpha=4.574e-01, previous alpha=4.297e-01, with an active set of 5 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.167e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.083e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.083e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.083e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=9.583e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=9.583e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=9.583e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=9.583e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=9.583e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 11 iterations, alpha=1.000e-01, previous alpha=9.583e-02, with an active set of 8 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_ll_n25k2

# %%
OM_W_ll_n25k1 = experiment_nk(LassoLars(alpha=1e-5), n=25, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k1, walsh_basis=True, csv_name="CSVs/OM_W_ll_n25k1")
OM_W_ll_n25k2 = experiment_nk(LassoLars(alpha=1e-5), n=25, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n25k2, walsh_basis=True, csv_name="CSVs/OM_W_ll_n25k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.556e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.704e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.704e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 12 iterations, alpha=5.556e-02, previous alpha=3.704e-02, with an active set of 9 regressors.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=6.710e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 14 iterations, alpha=4.010e-01, previous alpha=3.928e-01, with an active set of 9 regressors.
#   warnings.warn(
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_ll_n25k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=4.622e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=4.558e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=4.541e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=4.533e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=4.513e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=4.488e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 24 iterations, i.e. alpha=3.511e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 24 iterations, i.e. alpha=3.511e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 24 iterations, i.e. alpha=3.511e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 24 iterations, i.e. alpha=3.478e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=3.215e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=3.209e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 26 iterations, alpha=3.215e-01, previous alpha=3.146e-01, with an active set of 9 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 12 iterations, alpha=1.306e-01, previous alpha=1.241e-01, with an active set of 7 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.042e+00, with an active set of 5 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.042e+00, with an active set of 5 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=5.211e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=5.211e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=3.625e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=3.592e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 19 iterations, alpha=3.577e-01, previous alpha=3.577e-01, with an active set of 8 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.630e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=8.148e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=8.148e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=8.148e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=8.148e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=8.148e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=8.148e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=8.148e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=8.148e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=6.296e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=6.296e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=6.296e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=6.296e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=6.296e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 20 iterations, alpha=8.148e-02, previous alpha=6.296e-02, with an active set of 11 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.000e+00, with an active set of 4 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=8.800e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.800e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.800e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.800e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.800e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.400e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=5.347e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.900e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.900e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.900e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=4.900e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.150e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.150e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.150e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.150e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.150e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.850e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.850e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.850e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.850e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.850e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.650e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.650e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.650e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.650e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.650e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.650e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.350e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.350e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.350e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.350e-01, with an active set of 10 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 15 iterations, alpha=4.650e-01, previous alpha=3.350e-01, with an active set of 10 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_ll_n25k2

# %% [markdown]
# ## n=50

# %% [markdown]
# ### Polynomial

# %%
OM_ML_poly_n50k1 = experiment_nk(LinearRegression(), n=50, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k1, walsh_basis=False, csv_name="CSVs/OM_ML_poly_n50k1")
OM_ML_poly_n50k2 = experiment_nk(LinearRegression(), n=50, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k2, walsh_basis=False, csv_name="CSVs/OM_ML_poly_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_poly_n50k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_poly_n50k2

# %%
OM_W_poly_n50k1 = experiment_nk(LinearRegression(), n=50, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k1, walsh_basis=True, csv_name="CSVs/OM_W_poly_n50k1")
OM_W_poly_n50k2 = experiment_nk(LinearRegression(), n=50, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k2, walsh_basis=True, csv_name="CSVs/OM_W_poly_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_poly_n50k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_poly_n50k2

# %% [markdown]
# ### Lars

# %%
OM_ML_lars_n50k1 = experiment_nk(Lars(), n=50, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k1, walsh_basis=False, csv_name="CSVs/OM_ML_lars_n50k1")
OM_ML_lars_n50k2 = experiment_nk(Lars(), n=50, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k2, walsh_basis=False, csv_name="CSVs/OM_ML_lars_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=1.362e+00, with an active set of 26 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=8.883e-01, with an active set of 26 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=8.406e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=6.410e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=5.768e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=5.757e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=5.613e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=5.591e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=5.505e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=5.475e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=5.058e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=4.441e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=3.666e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=3.555e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=3.531e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=3.360e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=2.827e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=2.250e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=2.102e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.621e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.408e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.404e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.357e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.319e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.225e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.186e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.174e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.078e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.039e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.007e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=8.894e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=7.852e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=7.668e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=6.081e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=5.035e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=3.678e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=2.854e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.018e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.505e-01, with an active set of 25 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.177e-01, with an active set of 25 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=2.017e-01, with an active set of 25 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.913e-01, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.695e-01, with an active set of 26 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.500e-01, with an active set of 26 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.360e-01, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.298e-01, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.133e-01, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=9.040e-02, with an active set of 26 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=8.648e-02, with an active set of 26 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=8.204e-02, with an active set of 26 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=7.255e-02, with an active set of 26 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=5.588e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=5.388e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=5.153e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.494e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.768e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.502e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.237e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=2.612e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=2.198e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.918e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=7.974e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=6.867e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=5.606e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=5.479e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=5.376e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=5.338e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=5.170e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=5.063e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.081e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.770e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.446e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.250e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.032e-05, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=6.172e-02, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=4.805e-02, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=4.452e-02, with an active set of 25 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=3.953e-02, with an active set of 26 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=3.793e-02, with an active set of 26 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.749e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.539e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.043e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=2.347e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=2.290e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.656e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.535e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.376e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=1.140e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=9.489e-02, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=7.668e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=7.470e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=6.854e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=6.467e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=5.558e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=5.189e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=4.632e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=4.337e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=3.848e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=3.755e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=3.116e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.957e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.520e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.464e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.117e-02, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=4.624e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=2.145e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.833e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.221e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=6.992e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=4.896e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=8.160e-05, with an active set of 28 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_lars_n50k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_lars_n50k2

# %%
OM_W_lars_n50k1 = experiment_nk(Lars(), n=50, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k1, walsh_basis=True, csv_name="CSVs/OM_W_lars_n50k1")
OM_W_lars_n50k2 = experiment_nk(Lars(), n=50, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k2, walsh_basis=True, csv_name="CSVs/OM_W_lars_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=4.201e-01, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=2.983e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=2.667e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.604e-01, with an active set of 30 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.498e-01, with an active set of 30 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.434e-01, with an active set of 31 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=1.458e-01, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=1.446e-01, with an active set of 32 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=1.370e-01, with an active set of 32 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.250e-01, with an active set of 33 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 43 iterations, i.e. alpha=1.286e+00, with an active set of 29 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 44 iterations, i.e. alpha=1.036e+00, with an active set of 30 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 44 iterations, i.e. alpha=1.014e+00, with an active set of 30 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 48 iterations, i.e. alpha=9.728e-01, with an active set of 34 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 53 iterations, i.e. alpha=1.157e+00, with an active set of 37 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=7.959e-01, with an active set of 26 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=7.293e-01, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 50 iterations, i.e. alpha=2.401e+00, with an active set of 38 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_lars_n50k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=5.028e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=5.115e-01, with an active set of 28 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=9.913e-01, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 43 iterations, i.e. alpha=9.461e-01, with an active set of 30 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=3.323e-01, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_lars_n50k2

# %% [markdown]
# ### Lasso

# %%
OM_ML_las_n50k1 = experiment_nk(Lasso(alpha=1e-5), n=50, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k1, walsh_basis=False, csv_name="CSVs/OM_ML_las_n50k1")
OM_ML_las_n50k2 = experiment_nk(Lasso(alpha=1e-5), n=50, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k2, walsh_basis=False, csv_name="CSVs/OM_ML_las_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_las_n50k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.616e-01, tolerance: 1.576e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.162e-01, tolerance: 2.778e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.206e-01, tolerance: 3.891e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.188e+00, tolerance: 4.941e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.718e+00, tolerance: 6.180e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.565e+00, tolerance: 7.624e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.379e+00, tolerance: 8.917e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.515e+00, tolerance: 1.005e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.048e+00, tolerance: 1.137e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.384e+00, tolerance: 1.253e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.395e+01, tolerance: 1.355e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.348e+01, tolerance: 1.475e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.234e+02, tolerance: 1.602e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 15/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.026e+02, tolerance: 1.718e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 16/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.316e+03, tolerance: 1.845e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 17/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.465e+03, tolerance: 1.954e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 18/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.742e+03, tolerance: 2.107e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 19/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.512e+03, tolerance: 2.241e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 20/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.189e+02, tolerance: 2.339e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 21/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.806e+02, tolerance: 2.466e+00
#   model = cd_fast.enet_coordinate_descent(
# Repeat 2
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.506e-01, tolerance: 1.425e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.394e-01, tolerance: 2.371e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.974e-01, tolerance: 3.643e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.138e+00, tolerance: 4.831e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.742e+00, tolerance: 6.116e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.284e+00, tolerance: 7.488e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.380e+00, tolerance: 8.807e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.449e+00, tolerance: 1.016e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.096e+00, tolerance: 1.157e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.272e+00, tolerance: 1.254e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.396e+01, tolerance: 1.388e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.790e+01, tolerance: 1.521e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.667e+02, tolerance: 1.628e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 15/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.772e+02, tolerance: 1.725e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 16/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.493e+03, tolerance: 1.843e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 17/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.857e+03, tolerance: 1.961e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 18/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.750e+03, tolerance: 2.096e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 19/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.976e+02, tolerance: 2.237e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 20/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.680e+02, tolerance: 2.375e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 21/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.806e+02, tolerance: 2.466e+00
#   model = cd_fast.enet_coordinate_descent(
# Repeat 3
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.553e-01, tolerance: 1.383e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.686e-01, tolerance: 2.454e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.843e-01, tolerance: 3.622e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.148e+00, tolerance: 4.992e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.677e+00, tolerance: 6.007e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.364e+00, tolerance: 7.127e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.398e+00, tolerance: 8.400e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.566e+00, tolerance: 9.715e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.261e+00, tolerance: 1.085e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.028e+00, tolerance: 1.199e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.486e+01, tolerance: 1.334e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.477e+01, tolerance: 1.445e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.710e+02, tolerance: 1.584e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 15/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.676e+02, tolerance: 1.724e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 16/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.280e+03, tolerance: 1.831e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 17/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.735e+03, tolerance: 1.963e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 18/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.620e+03, tolerance: 2.103e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 19/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.498e+03, tolerance: 2.239e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 20/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.012e+02, tolerance: 2.365e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 21/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.806e+02, tolerance: 2.466e+00
#   model = cd_fast.enet_coordinate_descent(
# Repeat 4
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.695e-01, tolerance: 1.574e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.870e-01, tolerance: 2.596e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.438e-01, tolerance: 3.873e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.147e+00, tolerance: 4.922e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.591e+00, tolerance: 6.217e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.181e+00, tolerance: 7.245e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.023e+00, tolerance: 8.419e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.439e+00, tolerance: 9.918e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.436e+00, tolerance: 1.093e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.948e+00, tolerance: 1.188e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.365e+01, tolerance: 1.324e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.587e+01, tolerance: 1.452e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.810e+02, tolerance: 1.574e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 15/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.502e+02, tolerance: 1.709e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 16/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.540e+03, tolerance: 1.846e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 17/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.902e+03, tolerance: 1.987e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 18/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.946e+03, tolerance: 2.098e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 19/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.323e+03, tolerance: 2.227e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 20/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.836e+02, tolerance: 2.330e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 21/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.806e+02, tolerance: 2.466e+00
#   model = cd_fast.enet_coordinate_descent(
# Repeat 5
# On train size 1/21
# On train size 2/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.378e-01, tolerance: 1.278e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 3/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.105e-01, tolerance: 2.679e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 4/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.345e-01, tolerance: 3.832e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 5/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.135e+00, tolerance: 5.212e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 6/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.764e+00, tolerance: 6.436e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 7/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.525e+00, tolerance: 7.984e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 8/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.466e+00, tolerance: 9.351e-01
#   model = cd_fast.enet_coordinate_descent(
# On train size 9/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.963e+00, tolerance: 1.075e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 10/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.983e+00, tolerance: 1.176e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.527e+00, tolerance: 1.299e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.397e+01, tolerance: 1.425e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.355e+01, tolerance: 1.535e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.475e+02, tolerance: 1.658e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 15/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.190e+02, tolerance: 1.747e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 16/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.240e+03, tolerance: 1.860e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 17/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.451e+03, tolerance: 1.987e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 18/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.315e+03, tolerance: 2.112e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 19/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.329e+03, tolerance: 2.233e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 20/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.546e+02, tolerance: 2.339e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 21/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.806e+02, tolerance: 2.466e+00
#   model = cd_fast.enet_coordinate_descent(
# Stored results as CSV at: CSVs/OM_ML_las_n50k2

# %%
OM_W_las_n50k1 = experiment_nk(Lasso(alpha=1e-5), n=50, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k1, walsh_basis=True, csv_name="CSVs/OM_W_las_n50k1")
OM_W_las_n50k2 = experiment_nk(Lasso(alpha=1e-5), n=50, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k2, walsh_basis=True, csv_name="CSVs/OM_W_las_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_las_n50k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.327e+00, tolerance: 1.221e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.702e+00, tolerance: 1.362e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.020e+01, tolerance: 1.469e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.493e+02, tolerance: 1.561e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 15/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.047e+01, tolerance: 1.687e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.340e+00, tolerance: 1.275e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.726e+00, tolerance: 1.390e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.960e+00, tolerance: 1.548e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.638e+02, tolerance: 1.681e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 15/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.086e+00, tolerance: 1.806e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.308e+00, tolerance: 1.152e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.645e+00, tolerance: 1.280e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.165e+00, tolerance: 1.401e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.528e+02, tolerance: 1.539e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 15/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.613e+00, tolerance: 1.658e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.521e+00, tolerance: 1.370e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.724e+00, tolerance: 1.454e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.828e+02, tolerance: 1.599e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 15/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.971e+00, tolerance: 1.716e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.264e+00, tolerance: 1.206e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 12/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.554e+00, tolerance: 1.349e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 13/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.082e+00, tolerance: 1.448e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 14/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.934e+02, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 15/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.549e+01, tolerance: 1.682e+00
#   model = cd_fast.enet_coordinate_descent(
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_las_n50k2

# %% [markdown]
# ### LassoLars

# %%
OM_ML_ll_n50k1 = experiment_nk(LassoLars(alpha=1e-5), n=50, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k1, walsh_basis=False, csv_name="CSVs/OM_ML_ll_n50k1")
OM_ML_ll_n50k2 = experiment_nk(LassoLars(alpha=1e-5), n=50, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k2, walsh_basis=False, csv_name="CSVs/OM_ML_ll_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_ll_n50k1
# Repeat 1
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.134e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=2.274e-01, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.784e-01, with an active set of 17 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=1.099e-01, with an active set of 20 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 47 iterations, i.e. alpha=1.090e-01, with an active set of 21 regressors, and the smallest cholesky pivot element being 6.989e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 49 iterations, alpha=1.090e-01, previous alpha=1.078e-01, with an active set of 22 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=4.702e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=4.611e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 8.941e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=4.559e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 47 iterations, alpha=4.702e-02, previous alpha=4.546e-02, with an active set of 24 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_ML_ll_n50k2

# %%
OM_W_ll_n50k1 = experiment_nk(LassoLars(alpha=1e-5), n=50, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k1, walsh_basis=True, csv_name="CSVs/OM_W_ll_n50k1")
OM_W_ll_n50k2 = experiment_nk(LassoLars(alpha=1e-5), n=50, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n50k2, walsh_basis=True, csv_name="CSVs/OM_W_ll_n50k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_ll_n50k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_ll_n50k2

# %% [markdown]
# ## n=100

# %% [markdown]
# ### Polynomial

# %%
OM_ML_poly_n100k1 = experiment_nk(LinearRegression(), n=100, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k1, walsh_basis=False, csv_name="CSVs/OM_ML_poly_n100k1")
OM_ML_poly_n100k2 = experiment_nk(LinearRegression(), n=100, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k2, walsh_basis=False, csv_name="CSVs/OM_ML_poly_n100k2")

# %%
OM_W_poly_n100k1 = experiment_nk(LinearRegression(), n=100, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k1, walsh_basis=True, csv_name="CSVs/OM_W_poly_n100k1")
OM_W_poly_n100k2 = experiment_nk(LinearRegression(), n=100, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k1, walsh_basis=True, csv_name="CSVs/OM_W_poly_n100k2")

# %% [markdown]
# ### Lars

# %%
OM_ML_lars_n100k1 = experiment_nk(Lars(), n=100, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k1, walsh_basis=False, csv_name="CSVs/OM_ML_lars_n100k1")
OM_ML_lars_n100k2 = experiment_nk(Lars(), n=100, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k2, walsh_basis=False, csv_name="CSVs/OM_ML_lars_n100k2")

# %%
OM_W_lars_n100k1 = experiment_nk(Lars(), n=100, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k1, walsh_basis=True, csv_name="CSVs/OM_W_lars_n100k1")
OM_W_lars_n100k2 = experiment_nk(Lars(), n=100, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k2, walsh_basis=True, csv_name="CSVs/OM_W_lars_n100k2")

# %% [markdown]
# ### Lasso

# %%
OM_ML_las_n100k1 = experiment_nk(Lasso(alpha=1e-5), n=100, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k1, walsh_basis=False, csv_name="CSVs/OM_ML_las_n100k1")
OM_ML_las_n100k2 = experiment_nk(Lasso(alpha=1e-5), n=100, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k2, walsh_basis=False, csv_name="CSVs/OM_ML_las_n100k2")

# %%
OM_W_las_n100k1 = experiment_nk(Lasso(alpha=1e-5), n=100, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k1, walsh_basis=True, csv_name="CSVs/OM_W_las_n100k1")
OM_W_las_n100k2 = experiment_nk(Lasso(alpha=1e-5), n=100, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k2, walsh_basis=True, csv_name="CSVs/OM_W_las_n100k2")

# %% [markdown]
# ### LassoLars

# %%
OM_ML_ll_n100k1 = experiment_nk(LassoLars(alpha=1e-5), n=100, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k1, walsh_basis=False, csv_name="CSVs/OM_ML_ll_n100k1")
OM_ML_ll_n100k2 = experiment_nk(LassoLars(alpha=1e-5), n=100, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k2, walsh_basis=False, csv_name="CSVs/OM_ML_ll_n100k2")

# %%
OM_W_ll_n100k1 = experiment_nk(LassoLars(alpha=1e-5), n=100, k=1, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k1, walsh_basis=True, csv_name="CSVs/OM_W_ll_n100k1")
OM_W_ll_n100k2 = experiment_nk(LassoLars(alpha=1e-5), n=100, k=2, problem_name="OneMaxEpistasis", interactions_nk=inter_n100k2, walsh_basis=True, csv_name="CSVs/OM_W_ll_n100k2")
# Out:
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_ll_n100k1
# Repeat 1
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 2
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 3
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 182 iterations, alpha=1.379e-02, previous alpha=1.379e-02, with an active set of 49 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 4
# On train size 1/21
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Repeat 5
# On train size 1/21
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 339 iterations, i.e. alpha=1.328e-02, with an active set of 49 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\ellae\anaconda3\envs\thesis\lib\site-packages\sklearn\linear_model\_least_angle.py:753: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 340 iterations, alpha=1.328e-02, previous alpha=1.326e-02, with an active set of 49 regressors.
#   warnings.warn(
# On train size 2/21
# On train size 3/21
# On train size 4/21
# On train size 5/21
# On train size 6/21
# On train size 7/21
# On train size 8/21
# On train size 9/21
# On train size 10/21
# On train size 11/21
# On train size 12/21
# On train size 13/21
# On train size 14/21
# On train size 15/21
# On train size 16/21
# On train size 17/21
# On train size 18/21
# On train size 19/21
# On train size 20/21
# On train size 21/21
# Stored results as CSV at: CSVs/OM_W_ll_n100k2
